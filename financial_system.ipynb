# %%
 def calculate_product_price(total_material_price, overhead_price, profit_percentage):
    selling_price = total_material_price + overhead_price * profit_percentage / 100
    return selling_price

def main():
    products = [
        {
            'name': 'BENZYL BENZOATE LOTION 25% w/v - 100ml PET Bottle: 500L Batch',
            'raw_material_quantities': {
                'Benzyl Benzoate BP': 125.00 ,
                'Emulsifying wax, non ionic':  17.50 ,
                'Light Liquid Paraffin':   8.00   ,
                'Jasmine Perfume': 0.25 ,
                'Cetostearyl Alcohol ':3,
                'Purified Water':358.50
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for this product
            }
        },

        {
            'name': 'POVIDONE IODINE 10% - 1000ml HDPE Bottle: 1000L Batch',
            'raw_material_quantities': {
                'Povidone Iodine ': 100,
                'Potassium Iodate': 0.50,
                'Glycerine':30.00 ,
                'Polysorbate 80':2.50 ,
                'Citric acid monohydrate':2.50 ,
                'Trisodium citrate': 8.00,
                'Purified Water': 900,
                # Add raw materials and quantities for Product 2
            },
            'packaging_material_quantities': {
                'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for Product 2
            }
        },
         {
            'name': 'POVIDONE IODINE 10% - 100ml HDPE Bottle: 1000L Batch',

            'raw_material_quantities': {
                'Povidone Iodine ': 100,
                'Potassium Iodate': 0.50,
                'Glycerine':30.00 ,
                'Polysorbate 80':2.50 ,
                'Citric acid monohydrate':2.50 ,
                'Trisodium citrate': 8.00,
                'Purified Water': 900,
                # Add raw materials and quantities for this product
             },
            'packaging_material_quantities': {
                'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'POVIDONE IODINE 10% - 200ml HDPE Bottle: 1000L Batch',
            'raw_material_quantities': {
                'Povidone Iodine ': 100,
                'Potassium Iodate': 0.50,
                'Glycerine':30.00 ,
                'Polysorbate 80':2.50 ,
                'Citric acid monohydrate':2.50 ,
                'Trisodium citrate': 8.00,
                'Purified Water': 900,
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'CALAMINE LOTION- 100ml PET Bottle: 1000L Batch',
            'raw_material_quantities': {
                'Calamine ': 150,
                'Zinc Oxide ': 50,
                'Xanthan gum': 2,
                'Bentonite':30,
                'Glycerin': 80,
                'Na. methyl paraben ': 1.2,
                'Na. propyl paraben ': 0.3,
                'Liquid Phenol': 4,
                'Trisodium citrate': 5,
                'Purified Water, ': 700,
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'SURGICAL SPIRIT- 100ml PET Bottle: 1000L Batch',
            'raw_material_quantities': {
                'Methylsalicylate': 5,
                'Diethylphthalate': 20,
                'Castor oil': 25,
                'IPA': 10,
                'Ethanol':950 
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'IODINE TINCTURE 25ml HDPE BOTTLE 350L BATCH',
            'raw_material_quantities': {
                'Potassium Iodide': 100,
                'Iodine Crystal': 150,
                'Ethanol': 200,
                'Purified water': 80,
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'STAVLON ANTISEPTIC - 1000ml HDPE Bottle: 1000L Batch',
            'raw_material_quantities': {
                'Chlorhexidine gluconate': 15.90,
                'Cetrimide ': 30,
                'Isopropyl alcohol': 21,
                'Pine Oil': 4.20,
                'Sunset yellow': 0.38,
                'Purified Water, ': 930,
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'STAVLON ANTISEPTIC - 200ml HDPE Bottle: 1000L Batch',
            'raw_material_quantities': {
                'Chlorhexidine gluconate': 15.9,
                'Cetrimide ': 30,
                'Isopropyl alcohol': 21,
                'Pine Oil': 5,
                'Sunset yellow': 0.38,
                'Purified Water, ': 930,
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'STAVLON ANTISEPTIC - 5000ml HDPE JERRYCAN: 1000L Batch',
            'raw_material_quantities': {
                'Chlorhexidine gluconate': 15.9,
                'Cetrimide ': 30,
                'Isopropyl alcohol': 21,
                'Pine Oil': 5,
                'Sunset yellow': 0.38,
                'Purified Water, ': 930,
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'STAVLON PLUS - 1000ml HDPE Bottle: 1000L Batch',
            'raw_material_quantities': {
                'Chlorhexidine gluconate': 75.0,
                'Cetrimide ': 150,
                'Isopropyl alcohol': 21,
                'Pine Oil': 5,
                'Sunset yellow': 0.38,
                'Purified Water, ': 930,
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'STAVLON PLUS - 5000ml HDPE Bottle: 1000L Batch',
            'raw_material_quantities': {
                'Chlorhexidine gluconate': 75.0,
                'Cetrimide ': 150,
                'Isopropyl alcohol': 21,
                'Pine Oil': 5,
                'Sunset yellow': 0.38,
                'Purified Water, ': 750,
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                 'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'KOFLIN  - 200ml PET Bottle: 1000L Batch',
            'raw_material_quantities': {
                'Chlorpheniramine': 0.4,
                'Citric acid monohydrate': 10,
                'Menthol': 0.8,
                'Sodium Saccharin': 1,
                'Carboxymethyl Cellulose Sodium': 6,
                'Sucrose': 80,
                'Raspberry flavour': 1.03,
                'Sodium benzoate': 8.00,
                'Ethanol': 0.4,
                'Carmosine red': 0.05,
                'Purified Water, ': 900,
                
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                 'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'KOFLIN  - 1000ml HDPE JERRYCAN: 1000L Batch',
            'raw_material_quantities': {
                 'Chlorpheniramine': 0.4,
                'Citric acid monohydrate': 10,
                'Menthol': 0.8,
                'Sodium Saccharin': 1,
                'Carboxymethyl Cellulose Sodium': 6,
                'Sucrose': 80,
                'Raspberry flavour': 1.03,
                'Sodium benzoate': 8.00,
                'Ethanol': 0.4,
                'Carmosine red': 0.05,
                'Purified Water, ': 900,
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'MAAGA - 200ml PET Bottle: 1000L Batch',
            'raw_material_quantities': {
                'Magnesium Trisilicate':50,
                'Sodium bicarbonate':50,
                'Light Magnesium carbonate':50,
                'Xanthan gum':2,
                'Sorbitol 70%':15,
                'Peppermint oil':0.5,
                'Polysorbate 20':0.03,
                'Sodium saccharin':0.6,
                'Na. methyl paraben':4,
                'Na.propyl paraben':1,
                'Purified Water,' :900,

                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'MAAGA - 100ml PET Bottle: 1000L Batch',
            'raw_material_quantities': {
                'Magnesium Trisilicate':50,
                'Sodium bicarbonate':50,
                'Light Magnesium carbonate':50,
                'Xanthan gum':2,
                'Sorbitol 70%':15,
                'Peppermint oil':0.5,
                'Polysorbate 20':0.03,
                'Sodium saccharin':0.6,
                'Na. methyl paraben':4,
                'Na.propyl paraben':1,
                'Purified Water,' :900,
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
               'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'HYDROVID  - 200ml PET Bottle: 1000L Batch',
            'raw_material_quantities': {
                'Hydrogen Peroxide 50%': 120,
                'Disodium Edetate ': 0.50,
                'Glycerin ': 20,
                'Purified Water, ': 859.50,
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Overheads': 120,
                'Miscellaneous ; Waste': 50,
                'Bottle and Cap 100ml': 100,
                'Label 100ml': 100,
                'Shipper- Corrugated box, 100 x 100': 100,
                'Mono carton & leaflet, 100ml': 100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'ORAKIM 1L, ORS   - 1 liter sachet: 115.56 KG Batch',
            'raw_material_quantities': {
                'Glucose Anhydrous': 75,
                'Potassium Chloride': 8.33,
                'Sodium Chloride': 14.45,
                'Trisodium Citrate': 16.11,
                'Orange fllavour': 1.67,
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Foil': 120,
                'Collector Box': 50,
                'Shipper- Corrugated box, 8 x 60': 100,
                'Miscellaneous ; Waste':100,

                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'CLOTRIKIM 15g - Clotrimazole 1% cream',
            'raw_material_quantities': {
                'Clotrimazole ':1,
                'Emulsifying wax':9,
                'Light Liquid paraffin':6,
                'White soft paraffin' :15,
                'Benzyl alcohol ':1,
                'Butylated hydroxy Toluene':0.02,
                'Purified water':67.98,

                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Al. Tube 15g':100,
                'Monocarton 15g':100,
                'Leaflet':120,
                'Shipper 1 x 500 tubes':50,
                'Overheads':100,
                'Miscellaneous, waste':100,

                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'CLOTRIKIM 20g - Clotrimazole 1% cream',
            'raw_material_quantities': {
                'Clotrimazole ':1,
                'Emulsifying wax':9,
                'Light Liquid paraffin':6,
                'White soft paraffin' :15,
                'Benzyl alcohol ':1,
                'Butylated hydroxy Toluene':0.02,
                'Purified water':67.98,
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Al. Tube 15g':100,
                'Monocarton 15g':100,
                'Leaflet':120,
                'Shipper 1 x 500 tubes':50,
                'Overheads':100,
                'Miscellaneous, waste':100,

                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'CLOTRIKIM 15g - Clotrimazole 1% cream',
            'raw_material_quantities': {
                'Miconazole Nitrate':2,
                'Clobetasol Propionate':0.05,
                'Gentamycin sulfate':0.16,
                'Cetostearyl alcohol':7.20,
                'Cetomacrogol 1000':2.25,
                'White soft paraffin':15.0,
                'Sodium hydrogen phosphate':0.30,
                'Light liquid paraffin':6.0,
                'Propylene glycol':10,
                'Benzyl alcohol':1,
                'Purified water':56.03,

                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Al. Tube 15g':100,
                'Monocarton 15g':100,
                'Leaflet':120,
                'Shipper 1 x 500 tubes':50,
                'Overheads':100,
                'Miscellaneous, waste':100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'CLOTRIKIM 15g - Clotrimazole 1% cream',
            'raw_material_quantities': {
                'Betamethasone dipropionate':0.0675,
                'Clotrimazole':1.0400,
                'Gentamycin sulfate':0.2195,
                'Cetostearyl alcohol':7.2,
                'Cetomacrogol 1000':1.8,
                'White soft paraffin':15.0,
                'Sodium hydrogen phosphate':0.3333,
                'Light liquid paraffin':3.0,
                'Propylene glycol':3.0,
                'Chlorocresol':0.1,
                'Purified water':68.2397,

                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Al. Tube 15g':100,
                'Monocarton 15g':100,
                'Leaflet':120,
                'Shipper 1 x 500 tubes':50,
                'Overheads':100,
                'Miscellaneous, waste':100,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'Cetirizine Hcl, 60ml',
            'raw_material_quantities': {
                'Cetirizine Hydrochloride BP':1,
                'Citric Acid anhydrous':1.25,
                'Trisodium Citrate':1.5,
                'Sodium methyl Paraben':2.0,
                'Sodium propyl Paraben':0.2,
                'Sucrose':100,
                'Sodium saccharin':0.5,
                'Raspberry flavor':2.0,
                'Glycerin':20,
                'Purified water':872,

                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Bottle and Cap, 60ml':1,
                'Label, 60ml':1,
                'Measuring cap':1,
                'Leaflet':1,
                'Monocarton, 60ml':1,
                'Shipper 1 x 100' :1,
                'Overheads':1,
                'Miscellaneous, waste':1,

                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'Paracetamol BP 60ml',
            'raw_material_quantities': {
                'Metronidazole Benzoate':64.32,
                'Citric Acid Monohydrate':1.2,
                'Sodium saccharin':1.2,
                'Sodium methyl Paraben':2.0,
                'Sodium propyl Paraben':0.2,
                'Sucrose':100,
                'Xanthan gum':2.5,
                'Propylene Glycol':6.0,
                'Tween 80':2.5,
                'Sorbitol 70%':20,
                'Mango flavor':3,
                'Sunset yellow':0.05,
                'Purified water':797,

                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Bottle and Cap, 60ml':1,
                'Label, 60ml':1,
                'Measuring cap':1,
                'Leaflet':1,
                'Monocarton, 60ml':1,
                'Shipper 1 x 100' :1,
                'Overheads':1,
                'Miscellaneous, waste':1,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'Paracetamol BP, 100ml',
            'raw_material_quantities': {
                'Paracetamol':24, 
                'Citric Acid anhydrous':2.5,
                'Trisodium Citrate':3,
                'Sodium methyl Paraben':2,
                'Sodium propyl Paraben':0.2,
                'Sucrose':150,
                'Disodium edtate':0.5,
                'Liquid glucose':200,
                'Propylene glycol':20,
                'Sorbitol 70%':30,
                'Tween 80':1,
                'Anhydrous colloidal silical':5,
                'Sodium saccharin':1.6,
                'Xanthan gum':2,
                'Strawberry flavor':2,
                'Carmoisine red':0.01,
                'Purified water':556,


                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Bottle and Cap, 60ml':1,
                'Label, 60ml':1,
                'Measuring cap':1,
                'Leaflet':1,
                'Monocarton, 60ml':1,
                'Shipper 1 x 100' :1,
                'Overheads':1,
                'Miscellaneous, waste':1,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'Ibuprofen BP, 60ml',
            'raw_material_quantities': {
                'Ibuprofen ':20,
                'Citric Acid anhydrous':1.2,
                'Tween 80':1,
                'Sodium methyl Paraben':2,
                'Sodium propyl Paraben':0.2,
                'Sucrose':150,
                'Sodium saccharin':1,
                'Disodium Edetate':0.5,
                'Glycerin':30,
                'Orange flavor':2.8,
                'Xanthan gum':2,
                'Anhydrous colloidal silica':5,
                'Sunset yellow':0.05,
                'Purified water':785,

                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Bottle and Cap, 60ml':1,
                'Label, 60ml':1,
                'Measuring cap':1,
                'Leaflet':1,
                'Monocarton, 60ml':1,
                'Shipper 1 x 100' :1,
                'Overheads':1,
                'Miscellaneous, waste':1,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'Ibuprofen BP, 100ml',
            'raw_material_quantities': {
                'Ibuprofen ':20,
                'Citric Acid anhydrous':1.2,
                'Tween 80':1,
                'Sodium methyl Paraben':2,
                'Sodium propyl Paraben':0.2,
                'Sucrose':150,
                'Sodium saccharin':1,
                'Disodium Edetate':0.5,
                'Glycerin':30,
                'Orange flavor':2.8,
                'Xanthan gum':2,
                'Anhydrous colloidal silica':5,
                'Sunset yellow':0.05,
                'Purified water':785,
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Bottle and Cap, 60ml':1,
                'Label, 60ml':1,
                'Measuring cap':1,
                'Leaflet':1,
                'Monocarton, 60ml':1,
                'Shipper 1 x 100' :1,
                'Overheads':1,
                'Miscellaneous, waste':1,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'Albendazole USP, 10ml',
            'raw_material_quantities': {
                'Albendazole ':40,
                'Citric Acid anhydrous':0.6,
                'Anhydrous colloidal silica':2.2,
                'Sodium methyl Paraben':2.0,
                'Sodium propyl Paraben':0.2,
                'Sucrose':100,
                'Xanthan gum':3.0,
                'Tween 80':1,
                'Sorbitol 70%':30,
                'Pineaple essence':3,
                'Sunset yellow':0.05,
                'Purified water':817,

                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Bottle and Cap, 60ml':1,
                'Label, 60ml':1,
                'Measuring cap':1,
                'Leaflet':1,
                'Monocarton, 60ml':1,
                'Shipper 1 x 100' :1,
                'Overheads':1,
                'Miscellaneous, waste':1,
                # Add packaging materials and quantities for this product
            }
        },
         {
            'name': 'Product 1',
            'raw_material_quantities': {
                'Mebendazole ':20,
                'Citric Acid anhydrous':1.0,
                'Anhydrous colloidal silica':2.4,
                'Sodium methyl Paraben':2.0,
                'Sodium propyl Paraben':0.2,
                'Sucrose':100,
                'Tween 80':1,
                'Sorbitol 70%':30,
                'Xantham gum':3,
                'Vanilla sssence':3,
                'Purified water':838,
                # Add raw materials and quantities for this product
            },
            'packaging_material_quantities': {
                'Bottle and Cap, 60ml':1,
                'Label, 60ml':1,
                'Measuring cap':1,
                'Leaflet':1,
                'Monocarton, 60ml':1,
                'Shipper 1 x 100' :1,
                'Overheads':1,
                'Miscellaneous, waste':1,
                # Add packaging materials and quantities for this product
            }
        },# Add more products with their raw materials and packaging materials
    ]

    overheads = [
        'Salaries',
        'Kitchen',
        'Lab',
        'Stationery',
        'NSSF 10%',
        'Generator fuel',
        'Umeme',
        'Depreciation',
        'Waste Collection and Disposal',
        'Environmental ( Pest monitoring & Control)',
        'Security',
        'Telephone & Internet',
        'Laundry',
        'Staff Medical',
        'Repairs and Maintainance',
        'Legal',
        'Car fuel',
        'Sewage and rubbish collection',
        'NWSC',
        'Marketing fees',
        'Audit' ,

        # Add other overheads
    ]

    overhead_prices = {}
    total_overhead_price = 0

    print("Enter prices for the following overheads:")
    for overhead in overheads:
        price = float(input(f"Enter the price for {overhead}: "))
        overhead_prices[overhead] = price
        total_overhead_price += price
    


    print("Total overhead price: $", total_overhead_price)

    for product in products:
        print(f"\nCalculating for {product['name']}:")
        
        raw_material_prices = {}
        packaging_material_prices = {}

        print("\nEnter unit prices for raw materials:")
        for material, default_quantity in product['raw_material_quantities'].items():
            unit_price = float(input(f"Enter the unit price for {material} in {product['name']}: "))
            quantity_input = input(f"Enter the quantity for {material} in {product['name']} (default: {default_quantity}): ")
            if quantity_input.strip():  # Check if the input is not just whitespace
                quantity = float(quantity_input)
            else:
                quantity = default_quantity
                
            raw_material_prices[material] = {'unit_price': unit_price, 'quantity': quantity }

        print("\nEnter unit prices for packaging materials:")
        for material, default_quantity in product['packaging_material_quantities'].items():
            unit_price = float(input(f"Enter the unit price for {material} in {product['name']}: "))
            quantity_input = input(f"Enter the quantity for {material} in {product['name']} (default: {default_quantity}): ")
            if quantity_input.strip():  # Check if the input is not just whitespace
                quantity = float(quantity_input)
            else:
                quantity = default_quantity
            packaging_material_prices[material] = {'unit_price': unit_price, 'quantity': quantity if quantity else default_quantity}

        raw_material_price = sum(entry['quantity'] * entry['unit_price'] for entry in raw_material_prices.values())
        packaging_material_price = sum(entry['quantity'] * entry['unit_price'] for entry in packaging_material_prices.values())
        total_material_price = raw_material_price + packaging_material_price


        print("\nRaw Material Price:", raw_material_price)
        print("Packaging Material Price:", packaging_material_price)
        print("Total Material Price:", total_material_price)
        print("Total Overhead Price:", total_overhead_price)

        profit_percentage = float(input("\nEnter the desired overhead percentage: "))
        product_price = calculate_product_price(total_material_price, total_overhead_price, profit_percentage)

        print("\nEstimated Production Price:", product_price)
        
        # Get the number of items in the batch from the user
        batch_size = int(input("Enter the number of items in the batch: "))
        
        # Calculate the price per item
        price_per_item = product_price / batch_size
        
        print("Price per Item:", price_per_item)

if __name__ == "__main__":
    main()
# Out:
# Enter prices for the following overheads:
# Enter the price for Salaries: 1
# Enter the price for Kitchen: 1
# Enter the price for Lab: 1
# Enter the price for Stationery: 1
# Enter the price for NSSF 10%: 1
# Enter the price for Generator fuel: 1
# Enter the price for Umeme: 1
# Enter the price for Depreciation: 1
# Enter the price for Waste Collection and Disposal: 1
# Enter the price for Environmental ( Pest monitoring & Control): 1
# Enter the price for Security: 1
# Enter the price for Telephone & Internet: 1
# Enter the price for Laundry: 1
# Enter the price for Staff Medical: 1
# Enter the price for Repairs and Maintainance: 1
# Enter the price for Legal: 1
# Enter the price for Car fuel: 1
# Enter the price for Sewage and rubbish collection: 1
# Enter the price for NWSC: 1
# Enter the price for Marketing fees: 1
# Enter the price for Audit: 1
# Total overhead price: $ 21.0
#
# Calculating for BENZYL BENZOATE LOTION 25% w/v - 100ml PET Bottle: 500L Batch:
#
# ...

# %% [markdown]
# 1#
